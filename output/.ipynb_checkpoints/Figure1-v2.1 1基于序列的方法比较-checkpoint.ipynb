# %% [markdown]
# # 1.4 comparation seq-based encode

# %%
from zzd.utils.assess import multi_scores
import numpy as np
import numpy as np
from sklearn import metrics
from matplotlib.ticker import MultipleLocator
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind


#load data
C1223_RF_EsmMean_c1 ,  C1223_RF_EsmMean_c2h,   C1223_RF_EsmMean_c2p,   C1223_RF_EsmMean_c3   = [],[],[],[]
C1223_RF_prottrans_c1, C1223_RF_prottrans_c2h, C1223_RF_prottrans_c2p, C1223_RF_prottrans_c3 = [],[],[],[]
C1223_RF_doc2vec_c1 ,  C1223_RF_doc2vec_c2h,   C1223_RF_doc2vec_c2p,   C1223_RF_doc2vec_c3   = [],[],[],[]
C1223_RF_dpc_c1 ,      C1223_RF_dpc_c2h,       C1223_RF_dpc_c2p,       C1223_RF_dpc_c3       = [],[],[],[]
C1223_RF_cksaap_c1 ,   C1223_RF_cksaap_c2h,    C1223_RF_cksaap_c2p,    C1223_RF_cksaap_c3    = [],[],[],[]
C1223_RF_ac_c1 ,       C1223_RF_ac_c2h,        C1223_RF_ac_c2p,        C1223_RF_ac_c3        = [],[],[],[]
C1223_RF_ct_c1 ,       C1223_RF_ct_c2h,        C1223_RF_ct_c2p,        C1223_RF_ct_c3        = [],[],[],[]

for i in range(10):
    C1223_RF_EsmMean_c1.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_EsmMean/c1_test_pred_{i}.txt")[:,-2:])
    C1223_RF_EsmMean_c2h.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_EsmMean/c2h_pred_{i}.txt")[:,-2:])
    C1223_RF_EsmMean_c2p.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_EsmMean/c2p_pred_{i}.txt")[:,-2:])  
    C1223_RF_EsmMean_c3.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_EsmMean/c3_pred_{i}.txt")[:,-2:])

    C1223_RF_prottrans_c1.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_prottrans/c1_test_pred_{i}.txt")[:,-2:])
    C1223_RF_prottrans_c2h.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_prottrans/c2h_pred_{i}.txt")[:,-2:])
    C1223_RF_prottrans_c2p.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_prottrans/c2p_pred_{i}.txt")[:,-2:])  
    C1223_RF_prottrans_c3.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_prottrans/c3_pred_{i}.txt")[:,-2:])
    
    C1223_RF_doc2vec_c1.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_doc2vec/c1_test_pred_{i}.txt")[:,-2:])
    C1223_RF_doc2vec_c2h.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_doc2vec/c2h_pred_{i}.txt")[:,-2:])
    C1223_RF_doc2vec_c2p.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_doc2vec/c2p_pred_{i}.txt")[:,-2:])  
    C1223_RF_doc2vec_c3.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_doc2vec/c3_pred_{i}.txt")[:,-2:])        

    C1223_RF_dpc_c1.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_dpc/c1_test_pred_{i}.txt")[:,-2:])
    C1223_RF_dpc_c2h.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_dpc/c2h_pred_{i}.txt")[:,-2:])
    C1223_RF_dpc_c2p.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_dpc/c2p_pred_{i}.txt")[:,-2:])  
    C1223_RF_dpc_c3.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_dpc/c3_pred_{i}.txt")[:,-2:])  

    C1223_RF_cksaap_c1.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_cksaap/c1_test_pred_{i}.txt")[:,-2:])
    C1223_RF_cksaap_c2h.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_cksaap/c2h_pred_{i}.txt")[:,-2:])
    C1223_RF_cksaap_c2p.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_cksaap/c2p_pred_{i}.txt")[:,-2:])  
    C1223_RF_cksaap_c3.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_cksaap/c3_pred_{i}.txt")[:,-2:])  

    C1223_RF_ac_c1.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_ac/c1_test_pred_{i}.txt")[:,-2:])
    C1223_RF_ac_c2h.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_ac/c2h_pred_{i}.txt")[:,-2:])
    C1223_RF_ac_c2p.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_ac/c2p_pred_{i}.txt")[:,-2:])  
    C1223_RF_ac_c3.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_ac/c3_pred_{i}.txt")[:,-2:])  
    
    C1223_RF_ct_c1.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_ct/c1_test_pred_{i}.txt")[:,-2:])
    C1223_RF_ct_c2h.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_ct/c2h_pred_{i}.txt")[:,-2:])
    C1223_RF_ct_c2p.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_ct/c2p_pred_{i}.txt")[:,-2:])  
    C1223_RF_ct_c3.append(
        np.genfromtxt(f"./preds/10folds_C1223_Xgboost_ct/c3_pred_{i}.txt")[:,-2:])  

    

  
    
    
    
#(2)统计AUPRC值 论文的图
data = [[C1223_RF_EsmMean_c1 ,  C1223_RF_EsmMean_c2h,   C1223_RF_EsmMean_c2p,   C1223_RF_EsmMean_c3   ],
        [C1223_RF_prottrans_c1, C1223_RF_prottrans_c2h, C1223_RF_prottrans_c2p, C1223_RF_prottrans_c3 ],
        
        [C1223_RF_cksaap_c1 ,   C1223_RF_cksaap_c2h,    C1223_RF_cksaap_c2p,    C1223_RF_cksaap_c3    ],
        [C1223_RF_dpc_c1 ,      C1223_RF_dpc_c2h,       C1223_RF_dpc_c2p,       C1223_RF_dpc_c3       ],
        [C1223_RF_ct_c1 ,       C1223_RF_ct_c2h,        C1223_RF_ct_c2p,        C1223_RF_ct_c3        ],               
        
        #[C1223_RF_doc2vec_c1 ,  C1223_RF_doc2vec_c2h,   C1223_RF_doc2vec_c2p,   C1223_RF_doc2vec_c3   ],
        [C1223_RF_ac_c1 ,       C1223_RF_ac_c2h,        C1223_RF_ac_c2p,        C1223_RF_ac_c3        ],      
       ]

auprc_6_4_10_12 = np.zeros((6,4,10,12))  #10种方法 4个测试集 10次重复 12种指标
auprc_6_4_10 = np.zeros((6,4,10))   #10种方法 4个测试集 10次重复 1种指标
auprc_6_4_avg = np.zeros((6,4,1))    #10种方法 4个测试集 10次重复平均值 1种指标

for i_m in range(6): #10种方法    
    for i_t in range(4):#4个测试集
        tmp = [multi_scores(data[i_m][i_t][_][:,0], data[i_m][i_t][_][:,1], show=False)
               for _ in range(10)]
        tmp = np.array(tmp) #(10,12)
        
        auprc_6_4_10_12[i_m,i_t] = tmp 

auprc_6_4_10 = auprc_6_4_10_12[:,:,:,-1]
auprc_6_4_avg = auprc_6_4_10.mean(2)

# %%
np.set_printoptions(suppress=True)

# "\t".join([str(f"{a:.1f}±{b:.1f}") for a,b in zip(single_sc_mean[:4],single_sc_std[:4])]) + "\t" +

keep_index = np.array([False,False,False,False,  True,True,True,  False,False,True,False,True])
print (np.array("TP	TN	FP	FN	PPV	TPR	TNR	Acc	mcc	f1	AUROC	AUPRC".split("\t"))[keep_index])
for t in range(4):
    print(f' ')
    for m in range(6):
        tmp = auprc_6_4_10_12[m,t]
        single_sc_mean = tmp.mean(0)
        single_sc_std = tmp.std(0)
        
        print(
              "\t".join([str(f"{a:.3f}±{b:.3f}") for a,b in zip(single_sc_mean[keep_index],single_sc_std[keep_index])]).replace("±0","±")
        )
            
        # break
        
    # break
# Out:
# ['PPV' 'TPR' 'TNR' 'f1' 'AUPRC']
#
# 0.930±.053	0.693±.051	0.995±.004	0.793±.044	0.867±.034
# 0.911±.036	0.693±.049	0.993±.003	0.786±.035	0.867±.027
# 0.921±.051	0.617±.049	0.994±.004	0.737±.039	0.824±.036
# 0.918±.040	0.605±.044	0.994±.003	0.728±.035	0.826±.035
# 0.915±.052	0.582±.053	0.995±.003	0.710±.048	0.808±.044
# 0.922±.060	0.572±.043	0.995±.003	0.705±.043	0.806±.035
#
# 0.881±.018	0.337±.048	0.995±.001	0.486±.050	0.692±.021
# 0.868±.025	0.345±.039	0.995±.001	0.493±.040	0.691±.031
# 0.824±.056	0.135±.036	0.997±.001	0.230±.052	0.554±.046
# 0.781±.056	0.126±.032	0.997±.001	0.215±.047	0.523±.031
# 0.806±.048	0.141±.034	0.996±.002	0.237±.049	0.510±.037
# 0.743±.092	0.094±.029	0.997±.001	0.166±.046	0.457±.045
#
# 0.803±.051	0.314±.041	0.992±.003	0.449±.044	0.607±.032
# 0.770±.061	0.322±.046	0.990±.003	0.453±.054	0.607±.051
# 0.797±.070	0.248±.029	0.994±.003	0.377±.039	0.548±.051
# 0.777±.054	0.256±.023	0.992±.003	0.384±.028	0.533±.044
# ...

# %%
#(3)统计图
#数据
labels = ["EsmMean","prottrans","EsmMsa",
          "PSSM",'one-hot',
          "CKSAAP","DPC","CT",
          "Doc2vec",'AC',]

colors = ["#FF8080","#FFABAB","#FFDBDB",'#DBDBDB','#00FBFB','#00DBDB','#00ABAB','#0B8B8B','#8B8B8B','#AB8B8B']

def middle_scatter(x):
    x = np.array(x)
    x.sort()
    return x[np.array([4,6,2,8,0,9,1,7,3,5])]


#格式
fig,ax = plt.subplots(1,1,figsize=(9,6))
ax.spines['top'].set_visible(False) 
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)

# ax.set_xticks()
ax.tick_params(bottom=False,top=False,left=True,right=False)
ax.set_xticklabels(('','','','','','regular test', '','','','',
                    '','','','','novel host', '','','','','','',
                    '','','','novel pathogen', '','','','','','',
                    '','','','','novel host & pathogen ', '','','','','','','',''),
                fontdict={"fontsize":12}, rotation=0)
ax.set_ylim(0,1)


# ax.set_title("",fontdict={"fontsize":15},y=1.05)
# ax.set_xlabel("",fontdict={"fontsize":15})
# ax.set_ylabel("AUPRC",fontdict={"fontsize":15})

#绘图
bps=[]
for idx_t in range(4):#每个测试集
    for idx_m in range(10):#每种方法
        x = idx_t*11+idx_m
        y = auprc_10_4_10[idx_m][idx_t]
        # labels = [labels[idx_m],] if idx_m==0 else ['']
        #ax.scatter()
        
        bplot = ax.boxplot(y,positions=range(x,x+1),widths=0.8,patch_artist=True,labels=[labels[idx_m]], medianprops=dict(color='red'))
        bps.append(bplot)
        for patch in bplot['boxes']:
            patch.set_facecolor(colors[idx_m])     
            patch.set_zorder(1)
            
        # ax.scatter(x+np.arange(10)*0.03-0.15, midle_high_sort(y), s=1, color="#000000",)
        ax.scatter(x+np.arange(10)*0.03-0.15, middle_scatter(y), s=10, color="#FBFBFB",edgecolors="#3B3B3B")


# plt.legend(fontsize=15,shadow=False,framealpha=0,bbox_to_anchor=(1.09, 1.04, ))
plt.legend([bps[0]["boxes"][0],
            bps[1]["boxes"][0],
            bps[2]["boxes"][0],
            bps[3]["boxes"][0],
            bps[4]["boxes"][0],
            bps[5]["boxes"][0],
            bps[6]["boxes"][0],
            bps[7]["boxes"][0],
            bps[8]["boxes"][0],
            bps[9]["boxes"][0],
           ],
                     
           labels,
           shadow=False,framealpha=0,bbox_to_anchor=(1.1, 1.1, ),fontsize=13)

plt.savefig('./pics/Figure1_10种序列编码比较_论文.svg', dpi=600,bbox_inches = 'tight',format="svg")
# Out:
# /tmp/ipykernel_8712/3005864925.py:25: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(('','','','','','regular test', '','','','',

# %%
# np.set_printoptions(suppress=True)

# print("TP	TN	FP	FN	PPV	TPR	TNR	Acc	mcc	f1	AUROC	AUPRC")
# for m in range(10):
#     print(f'm_{m}')
#     for t in range(4):
#         tmp = auprc_10_4_10_scs[m,t]
#         single_sc_mean = tmp.mean(0)
#         single_sc_std = tmp.std(0)
#         # print("\t".join([str(f"{_:.1f}") for _ in single_sc_mean[:4]]) + "\t" +
#         #       "\t".join([str(f"{_:.3f}") for _ in single_sc_mean[4:]]))
        
#         print("\t".join([str(f"{a:.1f}±{b:.1f}") for a,b in zip(single_sc_mean[:4],single_sc_std[:4])]) + "\t" +
#               "\t".join([str(f"{a:.3f}±{b:.3f}") for a,b in zip(single_sc_mean[4:],single_sc_std[4:])]))
            
#         # break
        
#     # break

# %%
# #(3)统计图
# #数据
# labels = ["EsmMean","prottrans","EsmMsa","PSSM",
#           "CKSAAP","DPC",
#           "Doc2vec"]

# colors = ["#FF8080","#FFABAB","#FFDBDB",'#DBDBDB','#ABABAB','#00DBDB','#00ABAB']

# def midle_high_sort(x):
#     x = np.array(sorted(x))
#     x = np.hstack((x[np.arange(0,len(x),2)],np.flipud(x[np.arange(1,len(x),2)])))
#     return x

# #格式
# fig,ax = plt.subplots(1,1,figsize=(9,6))
# ax.spines['top'].set_visible(False) 
# ax.spines['right'].set_visible(False)
# ax.spines['left'].set_visible(True)
# ax.spines['bottom'].set_visible(True)

# # ax.set_xticks()
# ax.tick_params(bottom=False,top=False,left=True,right=False)
# ax.set_xticklabels(('','','','regular', '','','',
#                  '','','','novel host', '','','',
#                  '','','','novel pathogen', '','','',
#                  '','','','novel host-pathogen', '','','',),
#                 fontdict={"fontsize":13}, rotation=0)
# ax.set_ylim(0,1)


# ax.set_title("",fontdict={"fontsize":15},y=1.05)
# ax.set_xlabel("",fontdict={"fontsize":15})
# ax.set_ylabel("AUPRC",fontdict={"fontsize":15})

# #绘图
# bps=[]
# for idx_t in range(4):#每个测试集
#     for idx_m in range(7):#每种方法
#         x = idx_t*9+idx_m
#         y = auprc_7_4_10[idx_m][idx_t]
#         # labels = [labels[idx_m],] if idx_m==0 else ['']
#         #ax.scatter()
        
#         bplot = ax.boxplot(y,positions=range(x,x+1),widths=0.85,patch_artist=True,labels=[labels[idx_m]])
#         bps.append(bplot)
#         for patch in bplot['boxes']:
#             patch.set_facecolor(colors[idx_m])     
#             patch.set_zorder(1)
            
#         ax.scatter(x+np.arange(10)*0.03-0.15, midle_high_sort(y), s=1, color="#000000",)


# # plt.legend(fontsize=15,shadow=False,framealpha=0,bbox_to_anchor=(1.09, 1.04, ))
# plt.legend([bps[0]["boxes"][0],
#             bps[1]["boxes"][0],
#             bps[2]["boxes"][0],
#             bps[3]["boxes"][0],
#             bps[4]["boxes"][0],
#             bps[5]["boxes"][0],
#             bps[6]["boxes"][0]],
                     
#            labels,
#            shadow=False,framealpha=0,bbox_to_anchor=(1.09, 1.04, ),fontsize=15)

# plt.savefig('./pics/Figure1_序列编码比较.svg', dpi=600,bbox_inches = 'tight',format="svg")

# %%
#(3)统计图
#数据
labels = ["EsmMean","prottrans","EsmMsa","PSSM",
          "CKSAAP","DPC","CT",
          "Doc2vec",'AC',]

colors = ["#FF8080","#FFABAB","#FFDBDB",'#DBDBDB','#ABABAB','#00DBDB','#00ABAB','#0B8B8B','#8B8B8B']

def middle_scatter(x):
    x = np.array(x)
    x.sort()
    return x[np.array([4,6,2,8,0,9,1,7,3,5])]

#格式
fig,ax = plt.subplots(1,1,figsize=(9,6))
ax.spines['top'].set_visible(False) 
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)

# ax.set_xticks()
ax.tick_params(bottom=False,top=False,left=True,right=False)
ax.set_xticklabels(('','','','','','regular', '','','','',
                    '','','','','novel host', '','','','',
                    '','','','','novel pathogen', '','','','',
                    '','','','','novel host-pathogen', '','','','','','',),
                fontdict={"fontsize":13}, rotation=0)
ax.set_ylim(0,1)


ax.set_title("",fontdict={"fontsize":15},y=1.05)
ax.set_xlabel("",fontdict={"fontsize":15})
ax.set_ylabel("AUPRC",fontdict={"fontsize":15})

#绘图
bps=[]
for idx_t in range(4):#每个测试集
    for idx_m in range(9):#每种方法
        x = idx_t*10+idx_m
        y = auprc_10_4_10[idx_m][idx_t]
        # labels = [labels[idx_m],] if idx_m==0 else ['']
        #ax.scatter()
        
        bplot = ax.boxplot(y,positions=range(x,x+1),widths=0.8,patch_artist=True,labels=[labels[idx_m]],medianprops=dict(color='red'))
        bps.append(bplot)
        for patch in bplot['boxes']:
            patch.set_facecolor(colors[idx_m])     
            patch.set_zorder(1)
            
        ax.scatter(x+np.arange(10)*0.03-0.15, middle_scatter(y), s=1, color="#000000",)


# plt.legend(fontsize=15,shadow=False,framealpha=0,bbox_to_anchor=(1.09, 1.04, ))
plt.legend([bps[0]["boxes"][0],
            bps[1]["boxes"][0],
            bps[2]["boxes"][0],
            bps[3]["boxes"][0],
            bps[4]["boxes"][0],
            bps[5]["boxes"][0],
            bps[6]["boxes"][0],
            bps[7]["boxes"][0],
            bps[8]["boxes"][0],
           ],
                     
           labels,
           shadow=False,framealpha=0,bbox_to_anchor=(1.2, 1.2, ),fontsize=15)

plt.savefig('./pics/Figure1_9种序列编码比较.svg', dpi=600,bbox_inches = 'tight',format="svg")
# Out:
# /tmp/ipykernel_52522/374103647.py:23: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(('','','','','','regular', '','','','',

# %% [markdown]
# # 9种方法比较  paper

# %%
# from zzd.utils.assess import roc_curve_kfold,pr_curve_kfold,pr_curve,roc_curve,multi_scores
import numpy as np
import numpy as np
from sklearn import metrics
from matplotlib.ticker import MultipleLocator
import matplotlib.pyplot as plt
from scipy.stats import ttest_ind


#load data
C1223_RF_EsmMean_c1 ,  C1223_RF_EsmMean_c2h,   C1223_RF_EsmMean_c2p,   C1223_RF_EsmMean_c3   = [],[],[],[]
C1223_RF_prottrans_c1, C1223_RF_prottrans_c2h, C1223_RF_prottrans_c2p, C1223_RF_prottrans_c3 = [],[],[],[]
C1223_RF_EsmMsa_c1 ,   C1223_RF_EsmMsa_c2h,    C1223_RF_EsmMsa_c2p,    C1223_RF_EsmMsa_c3    = [],[],[],[]
C1223_RF_doc2vec_c1 ,  C1223_RF_doc2vec_c2h,   C1223_RF_doc2vec_c2p,   C1223_RF_doc2vec_c3   = [],[],[],[]
C1223_CNN_pssm_c1 ,    C1223_CNN_pssm_c2h,     C1223_CNN_pssm_c2p,     C1223_CNN_pssm_c3     = [],[],[],[]
C1223_RF_dpc_c1 ,      C1223_RF_dpc_c2h,       C1223_RF_dpc_c2p,       C1223_RF_dpc_c3       = [],[],[],[]
C1223_RF_cksaap_c1 ,   C1223_RF_cksaap_c2h,    C1223_RF_cksaap_c2p,    C1223_RF_cksaap_c3    = [],[],[],[]
C1223_RF_ac_c1 ,       C1223_RF_ac_c2h,        C1223_RF_ac_c2p,        C1223_RF_ac_c3        = [],[],[],[]
C1223_RF_ct_c1 ,       C1223_RF_ct_c2h,        C1223_RF_ct_c2p,        C1223_RF_ct_c3        = [],[],[],[]
C1223_RF_onehot_c1 ,   C1223_RF_onehot_c2h,    C1223_RF_onehot_c2p,    C1223_RF_onehot_c3    = [],[],[],[]

for i in range(10):
    C1223_RF_EsmMean_c1.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_EsmMean/c1_pred_{i}.txt")[:,-2:])
    C1223_RF_EsmMean_c2h.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_EsmMean/c2_host_unseen_pred_{i}.txt")[:,-2:])
    C1223_RF_EsmMean_c2p.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_EsmMean/c2_pathogen_unseen_pred_{i}.txt")[:,-2:])  
    C1223_RF_EsmMean_c3.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_EsmMean/c3_pred_{i}.txt")[:,-2:])

    C1223_RF_prottrans_c1.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_prottrans/c1_pred_{i}.txt")[:,-2:])
    C1223_RF_prottrans_c2h.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_prottrans/c2_host_unseen_pred_{i}.txt")[:,-2:])
    C1223_RF_prottrans_c2p.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_prottrans/c2_pathogen_unseen_pred_{i}.txt")[:,-2:])  
    C1223_RF_prottrans_c3.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_prottrans/c3_pred_{i}.txt")[:,-2:])
    
    C1223_RF_EsmMsa_c1.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_EsmMsa/c1_pred_{i}.txt")[:,-2:])
    C1223_RF_EsmMsa_c2h.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_EsmMsa/c2_host_unseen_pred_{i}.txt")[:,-2:])
    C1223_RF_EsmMsa_c2p.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_EsmMsa/c2_pathogen_unseen_pred_{i}.txt")[:,-2:])  
    C1223_RF_EsmMsa_c3.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_EsmMsa/c3_pred_{i}.txt")[:,-2:])
    
    C1223_RF_doc2vec_c1.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_doc2vec/c1_pred_{i}.txt")[:,-2:])
    C1223_RF_doc2vec_c2h.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_doc2vec/c2_host_unseen_pred_{i}.txt")[:,-2:])
    C1223_RF_doc2vec_c2p.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_doc2vec/c2_pathogen_unseen_pred_{i}.txt")[:,-2:])  
    C1223_RF_doc2vec_c3.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_doc2vec/c3_pred_{i}.txt")[:,-2:])        

    C1223_CNN_pssm_c1.append(
        np.genfromtxt(f"./preds/10folds_C1223_CNN_pssm/c1_pred_{i}.txt")[:,-2:])
    C1223_CNN_pssm_c2h.append(
        np.genfromtxt(f"./preds/10folds_C1223_CNN_pssm/c2_host_unseen_pred_{i}.txt")[:,-2:])
    C1223_CNN_pssm_c2p.append(
        np.genfromtxt(f"./preds/10folds_C1223_CNN_pssm/c2_pathogen_unseen_pred_{i}.txt")[:,-2:])  
    C1223_CNN_pssm_c3.append(
        np.genfromtxt(f"./preds/10folds_C1223_CNN_pssm/c3_pred_{i}.txt")[:,-2:])       

    C1223_RF_dpc_c1.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_dpc/c1_pred_{i}.txt")[:,-2:])
    C1223_RF_dpc_c2h.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_dpc/c2_host_unseen_pred_{i}.txt")[:,-2:])
    C1223_RF_dpc_c2p.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_dpc/c2_pathogen_unseen_pred_{i}.txt")[:,-2:])  
    C1223_RF_dpc_c3.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_dpc/c3_pred_{i}.txt")[:,-2:])  

    C1223_RF_cksaap_c1.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_cksaap/c1_pred_{i}.txt")[:,-2:])
    C1223_RF_cksaap_c2h.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_cksaap/c2_host_unseen_pred_{i}.txt")[:,-2:])
    C1223_RF_cksaap_c2p.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_cksaap/c2_pathogen_unseen_pred_{i}.txt")[:,-2:])  
    C1223_RF_cksaap_c3.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_cksaap/c3_pred_{i}.txt")[:,-2:])  

    C1223_RF_ac_c1.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_ac/c1_pred_{i}.txt")[:,-2:])
    C1223_RF_ac_c2h.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_ac/c2_host_unseen_pred_{i}.txt")[:,-2:])
    C1223_RF_ac_c2p.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_ac/c2_pathogen_unseen_pred_{i}.txt")[:,-2:])  
    C1223_RF_ac_c3.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_ac/c3_pred_{i}.txt")[:,-2:])  
    
    C1223_RF_ct_c1.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_ct/c1_pred_{i}.txt")[:,-2:])
    C1223_RF_ct_c2h.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_ct/c2_host_unseen_pred_{i}.txt")[:,-2:])
    C1223_RF_ct_c2p.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_ct/c2_pathogen_unseen_pred_{i}.txt")[:,-2:])  
    C1223_RF_ct_c3.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_ct/c3_pred_{i}.txt")[:,-2:])  
    
    C1223_RF_onehot_c1.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_ct/c1_pred_{i}.txt")[:,-2:])
    C1223_RF_onehot_c2h.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_ct/c2_host_unseen_pred_{i}.txt")[:,-2:])
    C1223_RF_onehot_c2p.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_ct/c2_pathogen_unseen_pred_{i}.txt")[:,-2:])  
    C1223_RF_onehot_c3.append(
        np.genfromtxt(f"./preds/10folds_C1223_RF_ct/c3_pred_{i}.txt")[:,-2:]) 
    

 
#(2)统计AUPRC值#paper的图
data = [[C1223_RF_EsmMean_c1 ,  C1223_RF_EsmMean_c2h,   C1223_RF_EsmMean_c2p,   C1223_RF_EsmMean_c3   ],
        [C1223_RF_prottrans_c1, C1223_RF_prottrans_c2h, C1223_RF_prottrans_c2p, C1223_RF_prottrans_c3 ],
        [C1223_RF_EsmMsa_c1 ,   C1223_RF_EsmMsa_c2h,    C1223_RF_EsmMsa_c2p,    C1223_RF_EsmMsa_c3    ],
        [C1223_CNN_pssm_c1 ,    C1223_CNN_pssm_c2h,     C1223_CNN_pssm_c2p,     C1223_CNN_pssm_c3     ],
        
        [C1223_RF_cksaap_c1 ,   C1223_RF_cksaap_c2h,    C1223_RF_cksaap_c2p,    C1223_RF_cksaap_c3    ],
        [C1223_RF_dpc_c1 ,      C1223_RF_dpc_c2h,       C1223_RF_dpc_c2p,       C1223_RF_dpc_c3       ],
        [C1223_RF_ct_c1 ,       C1223_RF_ct_c2h,        C1223_RF_ct_c2p,        C1223_RF_ct_c3        ],               
        
        [C1223_RF_doc2vec_c1 ,  C1223_RF_doc2vec_c2h,   C1223_RF_doc2vec_c2p,   C1223_RF_doc2vec_c3   ],
        [C1223_RF_ac_c1 ,       C1223_RF_ac_c2h,        C1223_RF_ac_c2p,        C1223_RF_ac_c3        ],
       
       ]

auprc_7_4_10 = []
auprc_7_4_avg = []

for i_m in range(7):
    auprc_m_4_10 = []
    auprc_m_4_avg = []
    for i_t in range(4):
        tmp = [multi_scores(
                    data[i_m][i_t][_][:,0],
                    data[i_m][i_t][_][:,1],show=False)[-1] 
               for _ in range(10)]
        auprc_m_4_10.append(tmp)
        auprc_m_4_avg.append(np.mean(tmp))
        
    auprc_7_4_10.append(auprc_m_4_10)
    auprc_7_4_avg.append(np.mean(auprc_m_4_avg))

# %%
#(3)统计图
#数据
labels = ["EsmMean","prottrans","EsmMsa","PSSM",
          "CKSAAP","DPC",
          "Doc2vec"]

colors = ["#FF8080","#FFABAB","#FFDBDB",'#DBDBDB','#ABABAB','#00DBDB','#00ABAB']

def midle_high_sort(x):
    x = np.array(sorted(x))
    x = np.hstack((x[np.arange(0,len(x),2)],np.flipud(x[np.arange(1,len(x),2)])))
    return x


#格式
fig,ax = plt.subplots(1,1,figsize=(9,6))
ax.spines['top'].set_visible(False) 
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(True)
ax.spines['bottom'].set_visible(True)

# ax.set_xticks()
ax.tick_params(bottom=False,top=False,left=True,right=False)
ax.set_xticklabels(('','','','regular', '','','',
                 '','','','novel host', '','','',
                 '','','','novel pathogen', '','','',
                 '','','','novel host-pathogen', '','','',),
                fontdict={"fontsize":13}, rotation=0)
ax.set_ylim(0,1)


ax.set_title("",fontdict={"fontsize":15},y=1.05)
ax.set_xlabel("",fontdict={"fontsize":15})
ax.set_ylabel("AUPRC",fontdict={"fontsize":15})

#绘图
bps=[]
for idx_t in range(4):#每个测试集
    for idx_m in range(7):#每种方法
        x = idx_t*9+idx_m
        y = auprc_7_4_10[idx_m][idx_t]
        # labels = [labels[idx_m],] if idx_m==0 else ['']
        #ax.scatter()
        
        bplot = ax.boxplot(y,positions=range(x,x+1),widths=0.85,patch_artist=True,labels=[labels[idx_m]])
        bps.append(bplot)
        for patch in bplot['boxes']:
            patch.set_facecolor(colors[idx_m])     
            patch.set_zorder(1)
            
        ax.scatter(x+np.arange(10)*0.03-0.15, midle_high_sort(y), s=1, color="#000000",)


# plt.legend(fontsize=15,shadow=False,framealpha=0,bbox_to_anchor=(1.09, 1.04, ))
plt.legend([bps[0]["boxes"][0],
            bps[1]["boxes"][0],
            bps[2]["boxes"][0],
            bps[3]["boxes"][0],
            bps[4]["boxes"][0],
            bps[5]["boxes"][0],
            bps[6]["boxes"][0]],
                     
           labels,
           shadow=False,framealpha=0,bbox_to_anchor=(1.09, 1.04, ),fontsize=15)

plt.savefig('./pics/Figure1_序列编码比较_paper.svg', dpi=600,bbox_inches = 'tight',format="svg")
# Out:
# /tmp/ipykernel_8712/917291568.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(('','','','regular', '','','',

# %%
# import matplotlib.pyplot as plt
# fig,ax = plt.subplots(1,1,figsize=(9,6))

# #set title
# # ax.set_title("Comparison of sequential encoder",fontdict={"fontsize":15},y=1.05)
# ax.set_xlabel("",fontdict={"fontsize":15})
# ax.set_ylabel("AUPRC",fontdict={"fontsize":15})
# ax.set_ylim(0,1)
# ax.set_xticks(np.arange(4))
# ax.set_xticklabels(('regular', 'novel host', 'novel pathogen', 'novel host-pathogen'),fontdict={"fontsize":13},
#                    rotation=0)
# ax.spines['top'].set_visible(False)
# ax.spines['right'].set_visible(False)

# labels = ["EsmMean","prottrans","EsmMsa",
#           "cksaap","dpc","pssm",
#           "doc2vec"]

# colors = ["#FF8080","#FFABAB","#FFDBDB",
#           '#00ABAB','#00DBDB','#DBDBDB',
#           '#ABABAB']

# # for i in np.arange(0,7):
# #     ax.bar(np.arange(4)+0.1*i-0.3,AuPRCs[i],yerr=stds[i], width=0.09,label=labels[i],color=colors[i],ecolor='#6B6B6B')

# Xs = []
# for i in np.arange(7):
#     x = np.arange(4)+0.1*i-0.3
#     y = AUPRCs[i]
#     #ax.bar(np.arange(4)+0.11*(i-1),AuPRCs[i],yerr=stds[i], width=0.1,label=labels[i],color=colors[i],ecolor='#6B6B6B')
#     ax.bar(x, y, width=0.1,label=labels[i],color=colors[i],ecolor='#6B6B6B') # 条形图 or barplot
#     ax.errorbar(x, y, yerr=stds[i],fmt='',color='#6B6B6B',elinewidth=1,capsize=4,ls="",alpha=0.8) # 标准差 or std line 
#     for j in range(4): # 散点 or dot
#         ax.scatter(x[j]+np.arange(10)*0.001-0.01, auprcs[i][j], s=1, color="#3B3B3B")  
#     Xs.append(x)

# for k in range(4):
#     tres = ttest_ind(auprcs[0][k],auprcs[1][k])
#     if tres.pvalue <0.05:
#         y = AUPRCs[0][k]+stds[0][k]+0.08
#         xs = Xs[0][k]
#         xe = Xs[1][k]
#         pvalue="**"
#         psig(ax,y,xs-0.02,xe+0.02,pvalue,yl=0.01,yr=0.01)
        
#     tres = ttest_ind(auprcs[1][k],auprcs[2][k])
#     if tres.pvalue <0.05:
#         y = AUPRCs[1][k]+stds[1][k]+0.08
#         xs = Xs[1][k]
#         xe = Xs[2][k]
#         pvalue="**"
#         psig(ax,y,xs-0.02,xe+0.02,pvalue,yl=0.01,yr=0.01)
        
        
#     tres = ttest_ind(auprcs[2][k],auprcs[3][k])
#     if tres.pvalue <0.05:
#         y = AUPRCs[2][k]+stds[2][k]+0.08
#         xs = Xs[2][k]
#         xe = Xs[3][k]
#         pvalue="**"
#         psig(ax,y,xs-0.02,xe+0.02,pvalue,yl=0.01,yr=0.01)
        
#     tres = ttest_ind(auprcs[3][k],auprcs[4][k])
#     if tres.pvalue <0.05:
#         y = AUPRCs[3][k]+stds[3][k]+0.08
#         xs = Xs[3][k]
#         xe = Xs[4][k]
#         pvalue="**"
#         psig(ax,y,xs-0.02,xe+0.02,pvalue,yl=0.01,yr=0.01)
        
#     tres = ttest_ind(auprcs[4][k],auprcs[5][k])
#     if tres.pvalue <0.05:
#         y = AUPRCs[4][k]+stds[4][k]+0.08
#         xs = Xs[4][k]
#         xe = Xs[5][k]
#         pvalue="**"
#         psig(ax,y,xs-0.02,xe+0.02,pvalue,yl=0.01,yr=0.01)
        
#     tres = ttest_ind(auprcs[5][k],auprcs[6][k])
#     if tres.pvalue <0.05:
#         y = AUPRCs[5][k]+stds[5][k]+0.08
#         xs = Xs[5][k]
#         xe = Xs[6][k]
#         pvalue="**"
#         psig(ax,y,xs-0.02,xe+0.02,pvalue,yl=0.01,yr=0.01)
# # plt.legend(fontsize=15,shadow=False,framealpha=0, bbox_to_anchor=(1.0, -0.05, ),ncol=4)
# plt.legend(fontsize=15,shadow=False,framealpha=0.8,facecolor='white')
# # frame.set_facecolor('green')
# plt.savefig('./pics/Figure_1F_sequential_encoder_comparation.svg', dpi=600,bbox_inches = 'tight',format="svg")
